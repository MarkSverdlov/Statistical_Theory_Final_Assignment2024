# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('games_may2024_cleaned.csv')

print(data)

data = data.loc[~pd.isna(data['metacritic_url']), ['AppID', 'name', 'price', 'metacritic_score', 'action','adventure','indie','massively multiplayer,'simulation', 'sport','strategy',release_date' , 'total_reviews', 'median_playtime','peak_ccu', 'user_ratio', 'estimated_owners']]

data['release_date2'] = data['release_date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d"))

data['age']=data['release_date2'].apply(lambda d: (cutoff_date - d).days)

data['user_ratio'] = data['positive'] / (data['positive'] + data['negative'])

data ['median_playtime'] = data['median_playtime_forever'] / data['age']

def parse(o):
    return [word[1:-1] for word in o[1:-1].split(', ')]

data['genres'] = data['genres'].apply(parse)

def is_action(s):
  if 'Action' in s:
    return 1
  else:
    return 0

data['action'] = data['genres'].apply(is_action)


def is_adventure(s):
  if 'Adventure' in s:
    return 1
  else:
    return 0

data['adventure'] = data['genres'].apply(is_adventure)

def is_indie(s):
  if 'Indie' in s:
    return 1
  else:
    return 0

data['indie'] = data['genres'].apply(is_indie)

def is_massively_multiplayer(s):
  if 'Massively multiplayer' in s:
    return 1
  else:
    return 0

data['massively multiplayer'] = data['genres'].apply(is_massively_multiplayer)

def is_simulation(s):
  if 'Simulation' in s:
    return 1
  else:
    return 0

data['simulation'] = data['genres'].apply(is_simulation)

def is_sport(s):
  if 'Sport' in s:
    return 1
  else:
    return 0

data['sport'] = data['genres'].apply(is_sport)

def is_strategy(s):
  if 'Strategy' in s:
    return 1
  else:
    return 0

data['strategy'] = data['genres'].apply(is_strategy)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-95c5c1949bef> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 data = pd.read_csv('games_may2024_cleaned.csv')
#       6
#       7 print(data)
#
# ...
