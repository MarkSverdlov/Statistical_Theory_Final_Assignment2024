# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('games_may2024_cleaned.csv')
data = data[~pd.isna(data['metacritic_url'])]
print(data)
# Out:
#         AppID                name release_date  required_age  price  \
# 2         570              Dota 2   2013-07-09             0   0.00
# 3      271590  Grand Theft Auto V   2015-04-13            17   0.00
# 5         440     Team Fortress 2   2007-10-10             0   0.00
# 6      105600            Terraria   2011-05-16             0   9.99
# 8      252490                Rust   2018-02-08            17  39.99
# ...       ...                 ...          ...           ...    ...
# 81329  333580     Slow Down, Bull   2015-04-20             0   1.99
# 81862  844740               SCARF   2018-09-14             0   4.99
# 82165  603840             Randall   2017-06-06             0  14.99
# 82698  370220         Animal Gods   2015-10-12             0   9.99
# 83457  102400    Vertex Dispenser   2011-06-10             0   9.99
#
#        dlc_count                               detailed_description  \
# 2              2  The most-played game on Steam. Every day, mill...
# ...

# %%
example = data.loc[2]
print(example)
# Out:
# AppID                                                                     570
# name                                                                   Dota 2
# release_date                                                       2013-07-09
# required_age                                                                0
# price                                                                     0.0
# dlc_count                                                                   2
# detailed_description        The most-played game on Steam. Every day, mill...
# about_the_game              The most-played game on Steam. Every day, mill...
# short_description           Every day, millions of players worldwide enter...
# reviews                     “A modern multiplayer masterpiece.” 9.5/10 – D...
# header_image                https://cdn.akamai.steamstatic.com/steam/apps/...
# website                                                 http://www.dota2.com/
# ...

# %%
import datetime
example["release_date"] = datetime.datetime.strptime(example["release_date"], "%Y-%m-%d")
# Out:
# C:\Users\TheHi\AppData\Local\Temp\ipykernel_6836\722758754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   example["release_date"] = datetime.datetime.strptime(example["release_date"], "%Y-%m-%d")

# %%
print(example["release_date"])
# Out:
# 2013-07-09 00:00:00

# %%
cutoff_date = datetime.datetime.strptime("2024-05-26", "%Y-%m-%d")

# %%
data['release_date2'] = data['release_date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d"))

# %%
data['age']=data['release_date2'].apply(lambda d: (cutoff_date - d).days)

# %%
data[['name', 'age', 'release_date']].sort_values('age', ascending=True)
# Out:
#                              name   age release_date
# 24466                 Paper Trail     5   2024-05-21
# 18906            Die by the Blade    10   2024-05-16
# 10246  Lorelei and the Laser Eyes    10   2024-05-16
# 3724               MULLET MADJACK    11   2024-05-15
# 7957                     ROBOBEAT    12   2024-05-14
# ...                           ...   ...          ...
# 1067        Half-Life: Blue Shift  8395   2001-06-01
# 1410                     Gothic 1  8473   2001-03-15
# 115                Counter-Strike  8607   2000-11-01
# 188                     Half-Life  9331   1998-11-08
# 1509                       POSTAL  9690   1997-11-14
#
# [3940 rows x 3 columns]

# %%
# Define the columns
columns = [
    'AppID', 'name', 'Age', 'Release_Date', 'Price',
    'Metacritic_Score', 'Size', 'User_Ratio',
    'Total_Reviews', 'Daily_Median_Playtime', 'Peak_CCU'
]
df = pd.DataFrame(data, columns=columns)
print("DataFrame:\n", df)
