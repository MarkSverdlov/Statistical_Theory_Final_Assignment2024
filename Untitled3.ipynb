# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

cutoff_date = datetime.datetime.strptime("2024-05-26", "%Y-%m-%d")

data = pd.read_csv('games_may20+24_cleaned.csv')

data = data.loc[~pd.isna(data['metacritic_url'])]

data['release_date'] = data['release_date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d"))

data['age']=data['release_date'].apply(lambda d: (cutoff_date - d).days)

def release_date_category(d):
    if d.year <= 1999:
        return '1997-1999'
    elif d.year <= 2002:
        return '2000-2002'
    elif d.year <= 2005:
        return '2003-2005'
    elif d.year <= 2008:
        return '2006-2008'
    elif d.year <= 2011:
        return '2009-2011'
    elif d.year <= 2014:
        return '2012-2014'
    elif d.year <= 2017:
        return '2015-2017'
    elif d.year <= 2020:
        return '2018-2020'
    elif d.year <= 2023:
        return '2021-2023'
    else:
        return '2024+'

data['release_date'] = data['release_date'].apply(release_date_category)

data['user_ratio'] = data['positive'] / (data['positive'] + data['negative'])

data ['median_playtime'] = data['median_playtime_forever'] / data['age']

data['total_reviews'] = data['positive'] + data['negative']

def parse(o):
    return [word[1:-1] for word in o[1:-1].split(', ')]

data['genres'] = data['genres'].apply(parse)

def add_commas(s):
    parts = []
    for i in range(len(s)-1, 0, -3):
        parts.append(s[max(0, i-2):i+1])
    parts = reversed(parts)
    return ','.join(parts)

def add_commas_to_interval(s):
    a, b = s.split(' - ', maxsplit=2)
    return '-'.join([add_commas(a), add_commas(b)])

data['estimated_owners'] = data['estimated_owners'].apply(add_commas_to_interval)


def is_action(s):
  if 'Action' in s:
    return 1
  else:
    return 0

data['action'] = data['genres'].apply(is_action)


def is_adventure(s):
  if 'Adventure' in s:
    return 1
  else:
    return 0

data['adventure'] = data['genres'].apply(is_adventure)

def is_indie(s):
  if 'Indie' in s:
    return 1
  else:
    return 0

data['indie'] = data['genres'].apply(is_indie)

def is_massively_multiplayer(s):
  if 'Massively Multiplayer' in s:
    return 1
  else:
    return 0

data['massively multiplayer'] = data['genres'].apply(is_massively_multiplayer)

def is_simulation(s):
  if 'Simulation' in s:
    return 1
  else:
    return 0

data['simulation'] = data['genres'].apply(is_simulation)

def is_sport(s):
  if 'Sports' in s:
    return 1
  else:
    return 0

data['sport'] = data['genres'].apply(is_sport)

def is_strategy(s):
  if 'Strategy' in s:
    return 1
  else:
    return 0

data['strategy'] = data['genres'].apply(is_strategy)


data = data.loc[:, ['AppID', 'name', 'age', 'release_date', 'price', 'metacritic_score',
                    'estimated_owners', 'action', 'adventure', 'indie', 'massively multiplayer',
                    'simulation', 'sport', 'strategy',
                    'user_ratio', 'total_reviews', 'median_playtime', 'peak_ccu']]
import plotly.express as px

columns = data.columns

px.histogram(data, "AppID")
px.histogram(data, 'age')
px.histogram(data, 'release_date', category_orders=dict(release_date=["1997-1999",
                                                                      "2000-2002",
                                                                      "2003-2005",
                                                                      "2006-2008",
                                                                      "2009-2011",
                                                                      "2012-2014",
                                                                      "2015-2017",
                                                                      "2018-2020",
                                                                      "2021-2023",
                                                                      "2024+"]))
px.histogram(data, 'price')
px.histogram(data, 'metacritic_score')
px.histogram(data, 'estimated_owners', category_orders=dict(estimated_owners=['0 - 0',
                                                                              '0 - 20000',
                                                                              '20000 - 50000',
                                                                              '50000 - 100000',
                                                                              '100000 - 200000',
                                                                              '200000 - 500000',
                                                                              '500000 - 1000000',
                                                                              '1000000 - 2000000',
                                                                              '2000000 - 5000000',
                                                                              '5000000 - 10000000',
                                                                              '10000000 - 2000000',
                                                                              '20000000 - 50000000',
                                                                              '50000000 - 100000000',
                                                                              '100000000 - 200000000',
                                                                              '200000000 - 500000000']))



cutoff_date.year
2024
data['action'].sum()
np.int64(1964)
data['adventure'].sum()
np.int64(1773)
data['indie'].sum()
np.int64(2190)
data['massively multiplayer'].sum()
np.int64(78)
data['simulation'].sum()
np.int64(594)
data['sport'].sum()
np.int64(110)
data['strategy'].sum()
np.int64(984)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-5ea5d5d2b75d> in <cell line: 8>()
#       6 cutoff_date = datetime.datetime.strptime("2024-05-26", "%Y-%m-%d")
#       7
# ----> 8 data = pd.read_csv('games_may20+24_cleaned.csv')
#       9
#      10 data = data.loc[~pd.isna(data['metacritic_url'])]
#
# ...

# %%
data['estimated_owners']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-07e5cc5c96ea> in <cell line: 1>()
# ----> 1 data['estimated_owners']
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv("games_may2024_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-15-01ba151e60d4> in <cell line: 1>()
# ----> 1 data = pd.read_csv("games_may2024_cleaned.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
# ...
